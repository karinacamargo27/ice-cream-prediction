# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar os dados
df = pd.read_csv('../data/ice_cream_sales.csv')

# Exibir as primeiras linhas
print(df.head())

# Resumo estatístico
print(df.describe())

# gráfico de dispersão
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['Temperatura'], y=df['Vendas'])
plt.xlabel("Temperatura (°C)")
plt.ylabel("Vendas de Sorvete")
plt.title("Relação entre Temperatura e Vendas de Sorvete")
plt.show()
# Out:
#    Temperatura  Vendas
# 0           22     120
# 1           23     130
# 2           24     140
# 3           25     150
# 4           26     160
#        Temperatura      Vendas
# count   175.000000  175.000000
# mean     34.457143  251.742857
# std       8.832226   88.820930
# min      18.000000   80.000000
# 25%      27.000000  176.500000
# 50%      34.000000  250.000000
# 75%      42.000000  325.000000
# max      50.000000  415.000000
